# %% [markdown]
# Idea: the thing from lecture where we synthesized vowels using F1, F2, F3, and combinations thereof.

# %%
from vowel_synthesizer import *
from fricative_synthesizer import *

# %%
formant_amps = {5000:(25,2400,7000),8650:(20,7000,15000)}#/s/ or /z/
# formant_amps = {2600:(37,1000,7000),8300:(2,7000,10000)}#/ʃ/
# formant_amps = {3000:(18,1000,6600),10000:(3,9000,14500)}#/f/
# formant_amps = {2800:(20,1000,5000),11250:(4,8200,15000)}#voiceless th
# formant_amps = {3000:(27,1500,6000),7500:(1,6000,10000)}#palatal fric
# formant_amps.update({max(formant_amps.keys())+f0*10:0})
dur = 1
scale = 750
noise_sample_increment = 1
generate_voiced_fricative(100,formant_amps,dur,noise_sample_increment=noise_sample_increment,scale=scale,plot=True,ofile="fricative.wav")

# %%
f0 = 100
# formant_amps = map_fq_to_harms({250:50,3500:45},f0)
# print(formant_amps)
# formant_amps = {7:40,11:32,23:24,33:0}#this works for /a/ with f0 = 101
formant_amps = {240:50,2400:45}
# formant_amps = {250:40,525:40}
formant_amps.update({max(formant_amps.keys())+f0*10:0})
print(formant_amps)
dur = 1
base_amp = 25
scale = 750
generate_flat_complex_wave(formant_amps,f0,dur,base_amp=base_amp,scale=1000,plot=True,ofile="complex.wav",formants_as_harms=False)

# %%
ipa_vowels_to_synth_cf('iu',[0.2,0.3],100,'synth_iu.wav',cf_len=0.01,trans_window=50)

# %%
ipa_vowels_to_synth_cf('iʌ',[0.2,0.3],100,'synth_iʌ.wav',cf_len=0.01,trans_window=50)

# %%
m = 4500
wl = 1000
wr = 2000
vs = np.random.triangular(m-wl,m,m+wr,size=10000)
# mxv = np.argmax([dist.pmf(k,n,al,be) for k in range(n)])
# print(al,mxv)
plt.figure(figsize=(20,20))
plt.hist(vs,bins=range(10000))
plt.xlim(0,None)
plt.show()
